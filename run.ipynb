# %% [markdown]
# # HSSFLDON RUN
#
# This notebook is being provided for running HSSFLDON in colab.

# %% [markdown]
# ## Clone Repo

# %%
# !git clone https://github.com/cmh02/HSSFLDON.git
# %cd HSSFLDON
# Out:
# Cloning into 'HSSFLDON'...
# remote: Enumerating objects: 1350, done.
# remote: Counting objects: 100% (481/481), done.
# remote: Compressing objects: 100% (197/197), done.
# remote: Total 1350 (delta 239), reused 443 (delta 211), pack-reused 869 (from 1)
# Receiving objects: 100% (1350/1350), 160.00 MiB | 27.01 MiB/s, done.
# Resolving deltas: 100% (627/627), done.
# /content/HSSFLDON

# %% [markdown]
# ## Install Requirements

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached appnope-0.1.4-py2.py3-none-any.whl.metadata (908 bytes)
# ...
#   Using cached asttokens-3.0.1-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# ...
#   Using cached comm-0.2.3-py3-none-any.whl.metadata (3.7 kB)
# ...
#   Using cached datasets-4.8.4-py3-none-any.whl.metadata (19 kB)
# ...
#   Using cached debugpy-1.8.20-cp312-cp312-manylinux_2_34_x86_64.whl.metadata (1.4 kB)
# ...
#   Using cached decorator-5.2.1-py3-none-any.whl.metadata (3.9 kB)
# ...
#   Using cached dill-0.4.1-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached executing-2.2.1-py2.py3-none-any.whl.metadata (8.9 kB)
# ...
#   Using cached fastapi-0.136.0-py3-none-any.whl.metadata (28 kB)
# ...
#   Using cached filelock-3.29.0-py3-none-any.whl.metadata (2.0 kB)
# ...
#   Using cached fsspec-2026.2.0-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached git_filter_repo-2.47.0-py3-none-any.whl.metadata (31 kB)
# ...
#   Using cached huggingface_hub-1.11.0-py3-none-any.whl.metadata (14 kB)
# ...

# %% [markdown]
# ## Pyproject Install

# %%
# %cd HSSFLDON
# Out:
# /content/HSSFLDON

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/HSSFLDON
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for hssfldon (pyproject.toml) ... done
#   Created wheel for hssfldon: filename=hssfldon-0.1.0-0.editable-py3-none-any.whl size=1549 sha256=694c8729edfd8a8e91062ab7b3f9dcdd90c7b53f0e8410ec54dd9d9cd503abff
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xy93yn97/wheels/01/4b/b2/dad7ceddd419a7454824001980674e3ab66d19b4774ef515b0
# Successfully built hssfldon
# ...

# %%
# !pip install torchvision
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 915.6/915.6 MB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 89.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: cuda-bindings
#     Found existing installation: cuda-bindings 13.2.0
#     Uninstalling cuda-bindings-13.2.0:
#       Successfully uninstalled cuda-bindings-13.2.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.11.0
#     Uninstalling torch-2.11.0:
#       Successfully uninstalled torch-2.11.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cuml-cu12 26.2.0 requires cuda-toolkit[cublas,cufft,curand,cusolver,cusparse]==12.*, but you have cuda-toolkit 13.0.2 which is incompatible.
# cudf-cu12 26.2.1 requires cuda-toolkit[nvcc,nvrtc]==12.*, but you have cuda-toolkit 13.0.2 which is incompatible.
# ...

# %% [markdown]
# ## Start up simulator

# %%
# !python3 -m hssfldon.simulator.simulator_main
# Out:
# Streaming output truncated to the last 5000 lines.
# [04-26 21:17:06][ModelManager 39675][DEBUG] Making predictions on batch 4627 of 4745 for output type HSSFLDON_PredictionOutputType.PROBABILITY_PREDICTION!
# [04-26 21:17:06][ModelManager 39675][DEBUG] Making predictions on batch 4627 of 4745 for output type HSSFLDON_PredictionOutputType.PROBABILITY_PREDICTION!
# [04-26 21:17:06][ModelManager 39675][DEBUG] Making predictions on batch 4627 of 4745 for output type HSSFLDON_PredictionOutputType.PROBABILITY_PREDICTION!
# [04-26 21:17:06][ModelManager 39675][DEBUG] Making predictions on batch 4627 of 4745 for output type HSSFLDON_PredictionOutputType.PROBABILITY_PREDICTION!
# [04-26 21:17:06][ModelManager 39675][DEBUG] Making predictions on batch 4628 of 4745 for output type HSSFLDON_PredictionOutputType.PROBABILITY_PREDICTION!
# [04-26 21:17:06][ModelManager 39675][DEBUG] Making predictions on batch 4628 of 4745 for output type HSSFLDON_PredictionOutputType.PROBABILITY_PREDICTION!
# ...
