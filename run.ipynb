# %% [markdown]
# # HSSFLDON RUN
#
# This notebook is being provided for running HSSFLDON in colab.

# %% [markdown]
# ## Install Requirements

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## Pyproject Install

# %%
# !pip install -e .

# %% [markdown]
# ## Start up simulator

# %%
# !python3 -m hssfldon.simulator.simulator_main
